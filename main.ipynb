# %% [markdown]
# # Apriori Association Rule on TV Shows Dataset

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd
from apyori import apriori
import numpy as np

# %% [markdown]
# Read the dataset and display it

# %%
data_set = pd.read_csv("dataset\TV Shows - Association Rule Learning.csv", header=None)
data_set
# Out:
#                  0              1                   2                 3   \
# 0         Cobra Kai          Lupin          12 Monkeys          Sherlock
# 1              Lost      Jack Ryan           The Flash   Game of thrones
# 2     Sex Education      Dr. House             Kingdom  The Walking Dead
# 3             Ozark  Sex Education         Constantine          Preacher
# 4            Naruto            NaN                 NaN               NaN
# ...             ...            ...                 ...               ...
# 9685      One Piece  The Blacklist  Two and a half men             Lupin
# 9686      One Piece      Mr. Robot          Succession             Ozark
# 9687      Daredevil       Atypical               Heros               NaN
# 9688       Absentia   The Newsroom        The Alienist               NaN
# 9689       Atypical            NaN                 NaN               NaN
#
#                   4                      5                    6       7   \
# 0                NaN                    NaN                  NaN     NaN
# 1     House of Cards             12 Monkeys              Vikings  Fringe
# 2                NaN                    NaN                  NaN     NaN
# 3            Vikings               The Tick                  NaN     NaN
# 4                NaN                    NaN                  NaN     NaN
# ...              ...                    ...                  ...     ...
# 9685            Dark  How I met your mother                  NaN     NaN
# 9686      12 Monkeys                Vikings  The Vampire Diaries     NaN
# 9687             NaN                    NaN                  NaN     NaN
# 9688             NaN                    NaN                  NaN     NaN
# 9689             NaN                    NaN                  NaN     NaN
#
#                  8             9   ...   22   23   24   25   26   27   28  \
# 0               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     The Mentalist  The Alienist  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...             ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 9685            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9686            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9687            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9688            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9689            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        29   30   31
# 0     NaN  NaN  NaN
# 1     NaN  NaN  NaN
# 2     NaN  NaN  NaN
# 3     NaN  NaN  NaN
# 4     NaN  NaN  NaN
# ...   ...  ...  ...
# 9685  NaN  NaN  NaN
# 9686  NaN  NaN  NaN
# 9687  NaN  NaN  NaN
# 9688  NaN  NaN  NaN
# 9689  NaN  NaN  NaN
#
# [9690 rows x 32 columns]

# %% [markdown]
# > We Notice that The Dataset Made out of 9690 Viewers data for 32 show daily

# %% [markdown]
# Now we should transform the dataframe to list of lists for apriori

# %%
transactions = []
for i in range(0, data_set.shape[0]):
    temp = []
    for j in range(0, data_set.shape[1]):
        if not data_set.loc[i,j] is np.nan:
            temp.append(data_set.loc[i,j])
    transactions.append(temp)

# %% [markdown]
# We chose the `min support` and `min confidence` based on Orange Tests

# %%
rules = apriori(transactions= transactions, min_support=0.005, min_confidence=0.6, min_lift=2)
association_results = list(rules)
print("The Total Rules: ", len(association_results))
# Out:
# The Total Rules:  21

# %% [markdown]
# > Notice we have 143 Rules

# %% [markdown]
# Now Time to display the Resuts

# %%
for i in range(len(association_results)):
    print(str(association_results[i]) + "\n\n")
# Out:
# RelationRecord(items=frozenset({'12 Monkeys', 'Dr. House', 'Sex Education'}), support=0.005159958720330237, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12 Monkeys', 'Dr. House'}), items_add=frozenset({'Sex Education'}), confidence=0.6172839506172839, lift=2.4148088338641425)])
#
#
# RelationRecord(items=frozenset({'Atypical', 'Berlin Station', 'Sex Education'}), support=0.009391124871001032, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Berlin Station'}), items_add=frozenset({'Sex Education'}), confidence=0.6408450704225352, lift=2.5069797062552954)])
#
#
# RelationRecord(items=frozenset({'Dr. House', 'Berlin Station', 'Sex Education'}), support=0.005985552115583075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. House', 'Berlin Station'}), items_add=frozenset({'Sex Education'}), confidence=0.6170212765957447, lift=2.4137812556369664)])
#
#
# RelationRecord(items=frozenset({'Berlin Station', 'Sex Education', 'Family Guy'}), support=0.006811145510835914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Family Guy'}), items_add=frozenset({'Sex Education'}), confidence=0.66, lift=2.5819136051675415)])
#
#
# RelationRecord(items=frozenset({'Sex Education', 'Berlin Station', 'Mr. Robot'}), support=0.008255933952528379, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Mr. Robot'}), items_add=frozenset({'Sex Education'}), confidence=0.6451612903225806, lift=2.5238647166838137)])
#
#
# RelationRecord(items=frozenset({'Stranger Things', 'Berlin Station', 'Sex Education'}), support=0.005366357069143447, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stranger Things', 'Berlin Station'}), items_add=frozenset({'Sex Education'}), confidence=0.6046511627906976, lift=2.365389490287388)])
#
#
# RelationRecord(items=frozenset({'The Blacklist', 'Berlin Station', 'Sex Education'}), support=0.00629514963880289, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Blacklist', 'Berlin Station'}), items_add=frozenset({'Sex Education'}), confidence=0.6224489795918368, lift=2.4350143771679043)])
#
#
# RelationRecord(items=frozenset({'Dr. House', 'Demon Slayer', 'Sex Education'}), support=0.005366357069143447, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. House', 'Demon Slayer'}), items_add=frozenset({'Sex Education'}), confidence=0.619047619047619, lift=2.421708287675183)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Demon Slayer', 'Family Guy'}), support=0.005572755417956657, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Demon Slayer', 'Family Guy'}), items_add=frozenset({'Ozark'}), confidence=0.6000000000000001, lift=3.097496004262121)])
#
#
# RelationRecord(items=frozenset({'Demon Slayer', 'Sex Education', 'Family Guy'}), support=0.005985552115583075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Demon Slayer', 'Family Guy'}), items_add=frozenset({'Sex Education'}), confidence=0.6444444444444445, lift=2.5210604225541653)])
#
#
# RelationRecord(items=frozenset({'Dr. House', 'The Blacklist', 'Sex Education'}), support=0.007017543859649123, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. House', 'The Blacklist'}), items_add=frozenset({'Sex Education'}), confidence=0.6181818181818182, lift=2.418321283077036)])
#
#
# RelationRecord(items=frozenset({'The Blacklist', 'Sex Education', 'Jack Ryan'}), support=0.006501547987616099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Blacklist', 'Jack Ryan'}), items_add=frozenset({'Sex Education'}), confidence=0.63, lift=2.4645538958417443)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Succession'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Succession'}), items_add=frozenset({'Ozark'}), confidence=0.6021505376344086, lift=3.108598140478114)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Demon Slayer', 'Sex Education'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Demon Slayer'}), items_add=frozenset({'Sex Education'}), confidence=0.620253164556962, lift=2.4264243700270334)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Sex Education', 'Mr. Robot'}), support=0.00784313725490196, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Mr. Robot'}), items_add=frozenset({'Sex Education'}), confidence=0.6031746031746031, lift=2.3596132033758193)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Atypical', 'The Blacklist', 'Mr. Robot'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'The Blacklist', 'Mr. Robot'}), items_add=frozenset({'Ozark'}), confidence=0.6125, lift=3.1620271710175816)])
#
#
# RelationRecord(items=frozenset({'The Blacklist', 'Atypical', 'Sex Education', 'Mr. Robot'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'The Blacklist', 'Mr. Robot'}), items_add=frozenset({'Sex Education'}), confidence=0.7000000000000001, lift=2.738393217601938)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'The Blacklist', 'Atypical', 'Sex Education'}), support=0.007739938080495356, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'The Blacklist'}), items_add=frozenset({'Sex Education'}), confidence=0.6198347107438017, lift=2.424787382764408)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Sex Education', 'The Mentalist'}), support=0.005159958720330237, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'The Mentalist'}), items_add=frozenset({'Sex Education'}), confidence=0.6172839506172839, lift=2.4148088338641425)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Cobra Kai', 'Sex Education', 'Mr. Robot'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Sex Education', 'Mr. Robot'}), items_add=frozenset({'Ozark'}), confidence=0.6292134831460674, lift=3.248310416454658)])
#
#
# RelationRecord(items=frozenset({'Ozark', 'Sex Education', 'Demon Slayer', 'Mr. Robot'}), support=0.005469556243550051, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Demon Slayer', 'Mr. Robot'}), items_add=frozenset({'Sex Education'}), confidence=0.670886075949367, lift=2.6244998288047503), OrderedStatistic(items_base=frozenset({'Sex Education', 'Demon Slayer', 'Mr. Robot'}), items_add=frozenset({'Ozark'}), confidence=0.6162790697674418, lift=3.181536593525046)])
